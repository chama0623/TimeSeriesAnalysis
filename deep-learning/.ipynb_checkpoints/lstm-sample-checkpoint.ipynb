# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras.layers import LSTM
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # 簡単なLSTM
# LSTMモデルを用いてsin波に対して学習・予測を行う.

# %% [markdown]
# ## データの生成
#
# データセットを作成する. 時系列データの場合, テーブルデータの手法(Hold-out, K-fold検証)のようにランダムにデータを分割することはできない. そこで, 訓練データをインデックス0～24に対してラベルをインデックス25のデータにする, インデックス1～25に対してラベルをインデックス26のデータにするというように先読みが発生しないようにデータセットを作成する.

# %%
def sin(x,T=100):
    # T : 周期
    return np.sin(2.0*np.pi*x/T)

def add_noise(T=100,ampl=0.05):
    # ノイズを付加する関数
    x=np.arange(0,2*T+1)
    noise = ampl*np.random.uniform(low=-1.0,high=1.0,size=len(x))
    return sin(x)+noise

f = add_noise()
f[:5]

plt.figure(facecolor="white")
plt.plot(f)
plt.show()

# %%
def make_dataset(low_data,n_prev=100):
    data,target=[],[]
    # 25個を1つの時系列として分割
    maxlen=25
    # [i:i+25]のtrainにi+25+1のtargetを対応させる
    for i in range(len(low_data)-maxlen):
        data.append(low_data[i:i+maxlen])
        target.append(low_data[i+maxlen])
    
    re_data = np.array(data).reshape(len(data),maxlen,1)
    re_target = np.array(target).reshape(len(data),1)
    
    return re_data,re_target

x_train,y_train = make_dataset(f)

# %%
x_train.shape,y_train.shape
# Out:
# ((176, 25, 1), (176, 1))

# %% [markdown]
# ## モデリング

# %%
len_of_sequence = x_train.shape[1]
in_out_neurons = 1
n_hidden = 300

model = Sequential()
model.add(LSTM(n_hidden,batch_input_shape=(None,len_of_sequence,in_out_neurons),return_sequences=False))
model.add(Dense(in_out_neurons))
model.add(Activation("linear"))
optimizer = Adam(lr=0.001)
model.compile(loss="mean_squared_error",optimizer=optimizer,metrics=["accuracy"])
# Out:
# 2022-03-23 21:14:49.632288: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:0a:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2022-03-23 21:14:49.644520: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:0a:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2022-03-23 21:14:49.644922: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:0a:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2022-03-23 21:14:49.646688: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-03-23 21:14:49.648587: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:0a:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2022-03-23 21:14:49.648978: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:0a:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2022-03-23 21:14:49.649259: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:0a:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2022-03-23 21:14:50.219540: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:0a:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2022-03-23 21:14:50.219932: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:0a:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2022-03-23 21:14:50.219949: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1609] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2022-03-23 21:14:50.220179: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:0a:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2022-03-23 21:14:50.220383: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 3929 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 2060, pci bus id: 0000:0a:00.0, compute capability: 7.5
# /usr/local/lib/python3.8/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)

# %%
# モデルを画像として出力
from keras.utils.vis_utils import plot_model
plot_model(model,show_shapes=True,to_file='LSTM-sample.png')

# %%
early_stopping = EarlyStopping(monitor="val_loss",mode="auto",patience=20)
history = model.fit(x_train,y_train,
         batch_size=300,
         epochs=100,
         validation_split=0.1,
         callbacks=[early_stopping])
# Out:
# Epoch 1/100
# 2022-03-23 21:14:52.471688: I tensorflow/stream_executor/cuda/cuda_dnn.cc:368] Loaded cuDNN version 8204
# 1/1 [==============================] - 3s 3s/step - loss: 0.5179 - val_loss: 0.1387
# Epoch 2/100
# 1/1 [==============================] - 0s 32ms/step - loss: 0.3391 - val_loss: 0.0464
# Epoch 3/100
# 1/1 [==============================] - 0s 30ms/step - loss: 0.2062 - val_loss: 0.0532
# Epoch 4/100
# 1/1 [==============================] - 0s 34ms/step - loss: 0.1272 - val_loss: 0.1951
# Epoch 5/100
# 1/1 [==============================] - 0s 32ms/step - loss: 0.1255 - val_loss: 0.2002
# Epoch 6/100
# 1/1 [==============================] - 0s 31ms/step - loss: 0.1002 - val_loss: 0.1091
# Epoch 7/100
# 1/1 [==============================] - 0s 31ms/step - loss: 0.0609 - val_loss: 0.0460
# Epoch 8/100
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0439 - val_loss: 0.0207
# Epoch 9/100
# 1/1 [==============================] - 0s 31ms/step - loss: 0.0419 - val_loss: 0.0132
# Epoch 10/100
# 1/1 [==============================] - 0s 31ms/step - loss: 0.0421 - val_loss: 0.0111
# Epoch 11/100
# 1/1 [==============================] - 0s 31ms/step - loss: 0.0384 - val_loss: 0.0098
# Epoch 12/100
# 1/1 [==============================] - 0s 32ms/step - loss: 0.0300 - val_loss: 0.0088
# Epoch 13/100
# 1/1 [==============================] - 0s 31ms/step - loss: 0.0194 - val_loss: 0.0093
# Epoch 14/100
# 1/1 [==============================] - 0s 31ms/step - loss: 0.0112 - val_loss: 0.0128
# Epoch 15/100
# 1/1 [==============================] - 0s 30ms/step - loss: 0.0106 - val_loss: 0.0159
# Epoch 16/100
# 1/1 [==============================] - 0s 32ms/step - loss: 0.0125 - val_loss: 0.0119
# Epoch 17/100
# 1/1 [==============================] - 0s 30ms/step - loss: 0.0075 - val_loss: 0.0046
# Epoch 18/100
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0032 - val_loss: 0.0018
# Epoch 19/100
# 1/1 [==============================] - 0s 30ms/step - loss: 0.0050 - val_loss: 0.0035
# Epoch 20/100
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0070 - val_loss: 0.0047
# Epoch 21/100
# 1/1 [==============================] - 0s 31ms/step - loss: 0.0060 - val_loss: 0.0037
# Epoch 22/100
# 1/1 [==============================] - 0s 31ms/step - loss: 0.0035 - val_loss: 0.0023
# Epoch 23/100
# 1/1 [==============================] - 0s 31ms/step - loss: 0.0023 - val_loss: 0.0019
# Epoch 24/100
# 1/1 [==============================] - 0s 32ms/step - loss: 0.0033 - val_loss: 0.0023
# Epoch 25/100
# 1/1 [==============================] - 0s 31ms/step - loss: 0.0054 - val_loss: 0.0023
# Epoch 26/100
# 1/1 [==============================] - 0s 32ms/step - loss: 0.0062 - val_loss: 0.0025
# Epoch 27/100
# 1/1 [==============================] - 0s 31ms/step - loss: 0.0053 - val_loss: 0.0041
# Epoch 28/100
# 1/1 [==============================] - 0s 30ms/step - loss: 0.0040 - val_loss: 0.0066
# Epoch 29/100
# 1/1 [==============================] - 0s 31ms/step - loss: 0.0035 - val_loss: 0.0087
# Epoch 30/100
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0033 - val_loss: 0.0091
# Epoch 31/100
# 1/1 [==============================] - 0s 31ms/step - loss: 0.0030 - val_loss: 0.0074
# Epoch 32/100
# 1/1 [==============================] - 0s 32ms/step - loss: 0.0026 - val_loss: 0.0045
# Epoch 33/100
# 1/1 [==============================] - 0s 31ms/step - loss: 0.0023 - val_loss: 0.0024
# Epoch 34/100
# 1/1 [==============================] - 0s 32ms/step - loss: 0.0024 - val_loss: 0.0020
# Epoch 35/100
# 1/1 [==============================] - 0s 31ms/step - loss: 0.0025 - val_loss: 0.0027
# Epoch 36/100
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0023 - val_loss: 0.0033
# Epoch 37/100
# 1/1 [==============================] - 0s 32ms/step - loss: 0.0021 - val_loss: 0.0034
# Epoch 38/100
# 1/1 [==============================] - 0s 32ms/step - loss: 0.0020 - val_loss: 0.0032

# %%
def plot_loss(history):
    """エポックごとの損失関数をプロットする関数
    
    Args:
    history : fittingの履歴
    
    Returns:
    None
    """
    # 損失関数の履歴を取得
    loss_train = history.history["loss"]
    loss_val = history.history["val_loss"]

    # 損失関数をプロット
    epochs=range(1,len(history.history["loss"])+1)
    plt.figure(facecolor="white")
    plt.plot(epochs,loss_train,label="Training loss")
    plt.plot(epochs,loss_val,label="Validation loss")
    plt.legend()
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.show()
    
def plot_acc(history):
    """エポックごとの正解率をプロットする関数
    
    Args:
    history : fittingの履歴
    
    Returns:
    None
    """
    acc_train = history.history['accuracy']
    acc_val = history.history['val_accuracy']
    epochs = range(1,len(history.history["accuracy"])+1)
    plt.figure(facecolor="white")
    plt.plot(epochs, acc_train, 'g', label='Training accuracy')
    plt.plot(epochs, acc_val, 'b', label='Validation accuracy')
    plt.legend()
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.show()

# %%
# 損失関数の描画
plot_loss(history)

# %%
# 正解率を描画
plot_acc(history)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [10], in <cell line: 2>()
#       1 # 正解率を描画
# ----> 2 plot_acc(history)
#
# Input In [8], in plot_acc(history)
#      24 def plot_acc(history):
#      25     """エポックごとの正解率をプロットする関数
#      26
#      27     Args:
#    (...)
#      31     None
#      32     """
# ---> 33     acc_train = history.history['accuracy']
#      34     acc_val = history.history['val_accuracy']
#      35     epochs = range(1,len(history.history["accuracy"])+1)
#
# KeyError: 'accuracy'

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'val_loss'])
