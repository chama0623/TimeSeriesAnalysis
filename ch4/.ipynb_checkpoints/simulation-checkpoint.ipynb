# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # 自分で作業を行う

# %%
# 会員ステータス
years = ["2014","2015","2016","2017","2018"]
userStatus = ["bronze","silver","gold","inactive"]

# 1000人分のステータスを生成, pは各年の生起確率
userYears = np.random.choice(years,1000,p=[0.1,0.1,0.15,0.30,0.35])
userStats = np.random.choice(userStatus,1000,p=[0.5,0.3,0.1,0.1])
yearJoined = pd.DataFrame({"yearJoined":userYears,"userStats":userStats})
yearJoined.head()
# Out:
#   yearJoined userStats
# 0       2017    silver
# 1       2016    bronze
# 2       2016    bronze
# 3       2014    bronze
# 4       2018    bronze

# %% [markdown]
# 団体は毎週3回メールを送ることを想定する. 会員は次の三種類の行動パターンをとることを想定する.
# - パターン1 : メールを一切開かない
# - パターン2 : メール開封率(関与率)が一定
# - パターン3 : 関与率に変化がある

# %%
NUM_EMAILS_SENT_WEEKLY = 3

# パターン1
def never_opens(period_rng):
    return []

def constant_open_rate(period_rng):
    n,p = NUM_EMAILS_SENT_WEEKLY,np.random.uniform(0,1)
    # 二項分布に従う確率をlen(period_rng)の長さの配列で返す
    num_opened = np.random.binomial(n,p,len(period_rng))
    return num_opened

def increasing_open_rate(period_rng):
    # random.uniform() : 第一引数から第二引数の範囲の乱数を返す
    return open_rate_with_factor_change(period_rng,np.random.uniform(1.01,1.30))

def decreasing_open_rate(period_rng):
    return open_rate_with_factor_change(period_rng,np.random.uniform(0.5,0.99))

def open_rate_with_factor_change(period_rng,fac):
    if len(period_rng)<1:
        return []
    else:
        # np.random.radient() : 第一引数から第二引数の範囲の整数を第三引数のサイズで返す
        times = np.random.randint(0,len(period_rng),int(0.1*len(period_rng)))
        num_opened = np.zeros(len(period_rng))
        # 週3回メールを送るシミュレーション
        for prd in range(0,len(period_rng),2):
            try:
                n,p = NUM_EMAILS_SENT_WEEKLY,np.random.uniform(0,1)
                num_opened[prd:(prd+2)]=np.random.binomial(n,p,2)
            except:
                num_opened[prd] = np.random.binomial(n,p,1)
        for t in range(len(times)):
            num_opened[times[t]] = 0
        return num_opened

# %% [markdown]
# 次の仮定をもとに寄付行動を定義する.
# - 寄付額はユーザーが会員であった期間に依存する
# - 各ユーザーの裕福ステータスを生成し, 寄付額は各ユーザーが寄付用に取り分けておいた安定した金額に関係する

# %%
# 寄付行動
def produce_donations(period_rng,user_behavior,num_emails,user_id,user_join_year):
    # ユーザーの所持金のリストを定義
    donations_amounts = np.array([0,25,50,70,100,250,500,1000,1500,2000])
    # ユーザーの所持金を生成
    user_has = np.random.choice(donations_amounts)
    email_fraction = num_emails/(NUM_EMAILS_SENT_WEEKLY*len(period_rng))
    # ユーザーの寄付額
    user_gives = user_has*email_fraction
    #ユーザーが寄付できる最大額のインデックスを取得
    user_gives_idx = np.where(user_gives>=donations_amounts)[0][-1]
    user_gives_idx = max(min(user_gives_idx,len(donations_amounts)-2),1)
    num_times_gave = np.random.poisson(2)*(2018-user_join_year)
    # 期間を生成
    times = np.random.randint(0,len(period_rng),num_times_gave)
    dons = pd.DataFrame({"user":[],"amount":[],"timestamp":[]})
    for n in range(num_times_gave):
        donation = donations_amounts[user_gives_idx+np.random.binomial(1,.3)]
        ts = str(period_rng[times[n]].start_time + random_weekly_time_delta())
        dons = dons.append(pd.DataFrame({"user":[user_id],"amount":[donation],"timestamp":[ts]}))
    # 寄付額が0のイベントを削除
    if dons.shape[0]>0:
        dons = dons[dons.amount!=0]
        
    return dons

# %%
def random_weekly_time_delta():
    """寄付を行った曜日と時刻を生成する関数
    """
    
    days_of_week = [d for d in range(7)]
    hours_of_day = [h for h in range(11,23)]
    minute_of_hour = [m for m in range(60)]
    second_of_minute = [s for s in range(60)]
    return (pd.Timedelta(str(np.random.choice(days_of_week))+" days")+
           pd.Timedelta(str(np.random.choice(hours_of_day))+" hours")+
           pd.Timedelta(str(np.random.choice(minute_of_hour))+" minute")+
           pd.Timedelta(str(np.random.choice(second_of_minute))+" seconds"))

# %%
# シミュレーションの実行
behaviors = [
    never_opens,
    constant_open_rate,
    increasing_open_rate,
    decreasing_open_rate
]
member_behaviors = np.random.choice(behaviors,1000,[0.2,0.5,0.1,0.2])
rng = pd.period_range("2015-02-14","2018-06-01",freq="W")
emails = pd.DataFrame({"member":[],"week":[],"emailsOpened":[]})
donations = pd.DataFrame({"member":[],"amount":[],"timestamp":[]})

for idx in range(yearJoined.shape[0]):
    # 入会した日を生成
    join_date = pd.Timestamp(yearJoined.iloc[idx].yearJoined)+pd.Timedelta(str(np.random.randint(0,365))+" days")
    join_date = min(join_date,pd.Timestamp("2018-06-01"))
    # ユーザーの入会以前のタイムスタンプがあってはいけない
    member_rng = rng[rng.start_time>join_date]
    
    if len(member_rng)<1:
        continue
    info = member_behaviors[idx](member_rng)
    if len(info)==len(member_rng):
        emails = emails.append(pd.DataFrame({
            "member": [idx]*len(info),
            "week" : [str(r.start_time) for r in member_rng],
            "emailsOpened" : info
        }))
        donations = donations.append(produce_donations(member_rng,member_behaviors[idx],sum(info),idx,join_date.year))

# %%
donations.set_index(pd.to_datetime(donations.timestamp),inplace=True)
donations.sort_index(inplace=True)
donations.groupby(pd.Grouper(freq="M")).amount.sum().plot()
# Out:
# <AxesSubplot:xlabel='timestamp'>

# %% [markdown]
# # 自動シミュレーション
#
# タクシーのシミュレーションを探索する. タクシー会社の様々な時間にシフトが始める車両の全体としての挙動を予測するために, 多数の個別のタクシーをサイバーシティに放って行動を報告するようにする.
#
# ジェネレータの例
# ```
# def simple_generator():
#     yield 1
#     yield 2
#     yield 3
#
# my_generator = simple_generator()
# print(next(my_generator))
# print(next(my_generator))
# print(next(my_generator))
# print(next(my_generator))
# ```
#
# 実行結果
# ```
# 1
# 2
# 3
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# <ipython-input-8-c8f40b8dccbd> in <module>
#       8 print(next(my_generator))
#       9 print(next(my_generator))
# ---> 10 print(next(my_generator))
#
# StopIteration:
# ```

# %%
# タクシーを生成
def taxi_id_number(num_taxis):
    arr = np.arange(num_taxis)
    np.random.shuffle(arr)
    for i in range(num_taxis):
        yield arr[i]

# %%
# シフトを生成
def shift_info():
    # シフト開始時間と平均乗車回数
    start_times_and_freqs = [(0,8),(8,30),(16,15)]
    indices = np.arange(len(start_times_and_freqs))
    while True:
        # 昼間をシフト台数が多く, 夜間は少なく設定
        idx = np.random.choice(indices,p=[0.25,0.5,0.25])
        start = start_times_and_freqs[idx]
        yield (start[0],start[0]+7.5,start[1])

# %%
def taxi_process(taxi_id_generator,shift_info_generator):
    # タクシーIDを取得
    taxi_id = next(taxi_id_generator)
    shift_start,shift_end,shift_mean_trips=next(shift_info_generator)
    actual_trips = round(np.random.normal(loc=shift_mean_trips,scale=2))
    average_trip_time = 6.5/shift_mean_trips*60
    # 平均乗車時間を分に変換
    between_events_time = 1.0/(shift_mean_trips-1)*60
    # タクシーが空車のまま走る時間は短い
    time = shift_start
    yield TimePoint(taxi_id,"start shift",time)
    
    deltaT = np.random.poisson(between_events_time)/60
    time+=deltaT
    for i in range(actual_trips):
        yield TimePoint(taxi_id,"pick up",time)
        deltaT = np.random.poisson(average_trip_time)/60
        time+=deltaT
        yield TimePoint(taxi_id,"drop off",time)
        deltaT = np.random.poisson(between_events_time)/60
        time+=deltaT
    deltaT = np.random.poisson(between_events_time)/60
    time+=deltaT
    yield TimePoint(taxi_id,"end shift",time)

# %%
# TimePoint
from dataclasses import dataclass
@dataclass
class TimePoint:
    taxi_id : int
    name : str
    time : float
    
    # ダンダーメソッド(TimePoint同士の比較)
    def __lt__(self,other):
        return self.time<other.time

# %%
import queue

class Simulator:
    def __init__(self,num_taxis):
        self._time_points = queue.PriorityQueue()
        taxi_id_generator = taxi_id_number(num_taxis)
        shift_info_generator = shift_info()
        self._taxis=[
            taxi_process(taxi_id_generator,shift_info_generator)
            for i in range(num_taxis)
        ]
        
        self._prepare_run()
       
    def _prepare_run(self):
        for t in self._taxis:
            while True:
                try:
                    e=next(t)
                    self._time_points.put(e)
                except:
                    break
                        
    def run(self):
        sim_time=0
        while sim_time<24:
            if self._time_points.empty():
                break
            p=self._time_points.get()
            sim_time=p.time
            print(p)

# %%
sim=Simulator(1000)
sim.run()
# Out:
# TimePoint(taxi_id=849, name='start shift', time=0)
# TimePoint(taxi_id=973, name='start shift', time=0)
# TimePoint(taxi_id=912, name='start shift', time=0)
# TimePoint(taxi_id=776, name='start shift', time=0)
# TimePoint(taxi_id=163, name='start shift', time=0)
# TimePoint(taxi_id=775, name='start shift', time=0)
# TimePoint(taxi_id=443, name='start shift', time=0)
# TimePoint(taxi_id=966, name='start shift', time=0)
# TimePoint(taxi_id=170, name='start shift', time=0)
# TimePoint(taxi_id=264, name='start shift', time=0)
# TimePoint(taxi_id=971, name='start shift', time=0)
# TimePoint(taxi_id=483, name='start shift', time=0)
# TimePoint(taxi_id=845, name='start shift', time=0)
# TimePoint(taxi_id=628, name='start shift', time=0)
# TimePoint(taxi_id=654, name='start shift', time=0)
# TimePoint(taxi_id=773, name='start shift', time=0)
# TimePoint(taxi_id=888, name='start shift', time=0)
# TimePoint(taxi_id=498, name='start shift', time=0)
# TimePoint(taxi_id=220, name='start shift', time=0)
# TimePoint(taxi_id=270, name='start shift', time=0)
# TimePoint(taxi_id=556, name='start shift', time=0)
# TimePoint(taxi_id=515, name='start shift', time=0)
# TimePoint(taxi_id=907, name='start shift', time=0)
# TimePoint(taxi_id=547, name='start shift', time=0)
# TimePoint(taxi_id=678, name='start shift', time=0)
# TimePoint(taxi_id=248, name='start shift', time=0)
# TimePoint(taxi_id=342, name='start shift', time=0)
# TimePoint(taxi_id=164, name='start shift', time=0)
# TimePoint(taxi_id=658, name='start shift', time=0)
# TimePoint(taxi_id=338, name='start shift', time=0)
# TimePoint(taxi_id=254, name='start shift', time=0)
# TimePoint(taxi_id=734, name='start shift', time=0)
# TimePoint(taxi_id=898, name='start shift', time=0)
# TimePoint(taxi_id=283, name='start shift', time=0)
# TimePoint(taxi_id=505, name='start shift', time=0)
# TimePoint(taxi_id=736, name='start shift', time=0)
# TimePoint(taxi_id=26, name='start shift', time=0)
# TimePoint(taxi_id=728, name='start shift', time=0)
# TimePoint(taxi_id=84, name='start shift', time=0)
# TimePoint(taxi_id=231, name='start shift', time=0)
# TimePoint(taxi_id=238, name='start shift', time=0)
# TimePoint(taxi_id=745, name='start shift', time=0)
# TimePoint(taxi_id=816, name='start shift', time=0)
# TimePoint(taxi_id=755, name='start shift', time=0)
# TimePoint(taxi_id=17, name='start shift', time=0)
# TimePoint(taxi_id=953, name='start shift', time=0)
# TimePoint(taxi_id=209, name='start shift', time=0)
# TimePoint(taxi_id=826, name='start shift', time=0)
# TimePoint(taxi_id=752, name='start shift', time=0)
# TimePoint(taxi_id=563, name='start shift', time=0)
# TimePoint(taxi_id=66, name='start shift', time=0)
# TimePoint(taxi_id=133, name='start shift', time=0)
# TimePoint(taxi_id=439, name='start shift', time=0)
# TimePoint(taxi_id=316, name='start shift', time=0)
# TimePoint(taxi_id=367, name='start shift', time=0)
# TimePoint(taxi_id=717, name='start shift', time=0)
# TimePoint(taxi_id=380, name='start shift', time=0)
# TimePoint(taxi_id=132, name='start shift', time=0)
# TimePoint(taxi_id=670, name='start shift', time=0)
# TimePoint(taxi_id=873, name='start shift', time=0)
# TimePoint(taxi_id=803, name='start shift', time=0)
# TimePoint(taxi_id=487, name='start shift', time=0)
# TimePoint(taxi_id=574, name='start shift', time=0)
# TimePoint(taxi_id=491, name='start shift', time=0)
# TimePoint(taxi_id=197, name='start shift', time=0)
# TimePoint(taxi_id=810, name='start shift', time=0)
# TimePoint(taxi_id=543, name='start shift', time=0)
# TimePoint(taxi_id=346, name='start shift', time=0)
# TimePoint(taxi_id=919, name='start shift', time=0)
# TimePoint(taxi_id=57, name='start shift', time=0)
# TimePoint(taxi_id=68, name='start shift', time=0)
# TimePoint(taxi_id=297, name='start shift', time=0)
# TimePoint(taxi_id=2, name='start shift', time=0)
# TimePoint(taxi_id=353, name='start shift', time=0)
# TimePoint(taxi_id=586, name='start shift', time=0)
# TimePoint(taxi_id=660, name='start shift', time=0)
# TimePoint(taxi_id=154, name='start shift', time=0)
# TimePoint(taxi_id=987, name='start shift', time=0)
# TimePoint(taxi_id=89, name='start shift', time=0)
# TimePoint(taxi_id=642, name='start shift', time=0)
# TimePoint(taxi_id=78, name='start shift', time=0)
# TimePoint(taxi_id=631, name='start shift', time=0)
# TimePoint(taxi_id=31, name='start shift', time=0)
# TimePoint(taxi_id=685, name='start shift', time=0)
# TimePoint(taxi_id=176, name='start shift', time=0)
# TimePoint(taxi_id=952, name='start shift', time=0)
# TimePoint(taxi_id=23, name='start shift', time=0)
# TimePoint(taxi_id=236, name='start shift', time=0)
# TimePoint(taxi_id=862, name='start shift', time=0)
# TimePoint(taxi_id=424, name='start shift', time=0)
# TimePoint(taxi_id=899, name='start shift', time=0)
# TimePoint(taxi_id=94, name='start shift', time=0)
# TimePoint(taxi_id=994, name='start shift', time=0)
# TimePoint(taxi_id=972, name='start shift', time=0)
# TimePoint(taxi_id=533, name='start shift', time=0)
# TimePoint(taxi_id=894, name='start shift', time=0)
# TimePoint(taxi_id=322, name='start shift', time=0)
# TimePoint(taxi_id=369, name='start shift', time=0)
# TimePoint(taxi_id=617, name='start shift', time=0)
# TimePoint(taxi_id=329, name='start shift', time=0)
# TimePoint(taxi_id=343, name='start shift', time=0)
# TimePoint(taxi_id=940, name='start shift', time=0)
# TimePoint(taxi_id=468, name='start shift', time=0)
# TimePoint(taxi_id=49, name='start shift', time=0)
# TimePoint(taxi_id=825, name='start shift', time=0)
# TimePoint(taxi_id=437, name='start shift', time=0)
# TimePoint(taxi_id=566, name='start shift', time=0)
# TimePoint(taxi_id=489, name='start shift', time=0)
# TimePoint(taxi_id=846, name='start shift', time=0)
# TimePoint(taxi_id=955, name='start shift', time=0)
# TimePoint(taxi_id=1, name='start shift', time=0)
# TimePoint(taxi_id=779, name='start shift', time=0)
# TimePoint(taxi_id=186, name='start shift', time=0)
# TimePoint(taxi_id=604, name='start shift', time=0)
# TimePoint(taxi_id=492, name='start shift', time=0)
# TimePoint(taxi_id=930, name='start shift', time=0)
# TimePoint(taxi_id=588, name='start shift', time=0)
# TimePoint(taxi_id=503, name='start shift', time=0)
# TimePoint(taxi_id=557, name='start shift', time=0)
# TimePoint(taxi_id=143, name='start shift', time=0)
# TimePoint(taxi_id=194, name='start shift', time=0)
# TimePoint(taxi_id=240, name='start shift', time=0)
# TimePoint(taxi_id=844, name='start shift', time=0)
# TimePoint(taxi_id=138, name='start shift', time=0)
# TimePoint(taxi_id=711, name='start shift', time=0)
# TimePoint(taxi_id=162, name='start shift', time=0)
# TimePoint(taxi_id=929, name='start shift', time=0)
# TimePoint(taxi_id=699, name='start shift', time=0)
# TimePoint(taxi_id=573, name='start shift', time=0)
# TimePoint(taxi_id=305, name='start shift', time=0)
# TimePoint(taxi_id=647, name='start shift', time=0)
# TimePoint(taxi_id=861, name='start shift', time=0)
# TimePoint(taxi_id=6, name='start shift', time=0)
# TimePoint(taxi_id=839, name='start shift', time=0)
# TimePoint(taxi_id=156, name='start shift', time=0)
# TimePoint(taxi_id=153, name='start shift', time=0)
# TimePoint(taxi_id=636, name='start shift', time=0)
# TimePoint(taxi_id=54, name='start shift', time=0)
# TimePoint(taxi_id=406, name='start shift', time=0)
# TimePoint(taxi_id=698, name='start shift', time=0)
# TimePoint(taxi_id=61, name='start shift', time=0)
# TimePoint(taxi_id=129, name='start shift', time=0)
# TimePoint(taxi_id=306, name='start shift', time=0)
# TimePoint(taxi_id=514, name='start shift', time=0)
# TimePoint(taxi_id=121, name='start shift', time=0)
# TimePoint(taxi_id=327, name='start shift', time=0)
# TimePoint(taxi_id=384, name='start shift', time=0)
# TimePoint(taxi_id=62, name='start shift', time=0)
# TimePoint(taxi_id=595, name='start shift', time=0)
# TimePoint(taxi_id=410, name='start shift', time=0)
# TimePoint(taxi_id=421, name='start shift', time=0)
# TimePoint(taxi_id=758, name='start shift', time=0)
# TimePoint(taxi_id=351, name='start shift', time=0)
# TimePoint(taxi_id=764, name='start shift', time=0)
# TimePoint(taxi_id=459, name='start shift', time=0)
# TimePoint(taxi_id=800, name='start shift', time=0)
# TimePoint(taxi_id=221, name='start shift', time=0)
# TimePoint(taxi_id=470, name='start shift', time=0)
# TimePoint(taxi_id=580, name='start shift', time=0)
# TimePoint(taxi_id=395, name='start shift', time=0)
# TimePoint(taxi_id=368, name='start shift', time=0)
# TimePoint(taxi_id=920, name='start shift', time=0)
# TimePoint(taxi_id=315, name='start shift', time=0)
# TimePoint(taxi_id=606, name='start shift', time=0)
# TimePoint(taxi_id=128, name='start shift', time=0)
# TimePoint(taxi_id=149, name='start shift', time=0)
# TimePoint(taxi_id=602, name='start shift', time=0)
# TimePoint(taxi_id=762, name='start shift', time=0)
# TimePoint(taxi_id=450, name='start shift', time=0)
# TimePoint(taxi_id=671, name='start shift', time=0)
# TimePoint(taxi_id=381, name='start shift', time=0)
# TimePoint(taxi_id=292, name='start shift', time=0)
# TimePoint(taxi_id=272, name='start shift', time=0)
# TimePoint(taxi_id=312, name='start shift', time=0)
# TimePoint(taxi_id=275, name='start shift', time=0)
# TimePoint(taxi_id=429, name='start shift', time=0)
# TimePoint(taxi_id=243, name='start shift', time=0)
# TimePoint(taxi_id=683, name='start shift', time=0)
# TimePoint(taxi_id=756, name='start shift', time=0)
# TimePoint(taxi_id=519, name='start shift', time=0)
# TimePoint(taxi_id=90, name='start shift', time=0)
# TimePoint(taxi_id=214, name='start shift', time=0)
# TimePoint(taxi_id=39, name='start shift', time=0)
# TimePoint(taxi_id=497, name='start shift', time=0)
# TimePoint(taxi_id=917, name='start shift', time=0)
# TimePoint(taxi_id=548, name='start shift', time=0)
# TimePoint(taxi_id=378, name='start shift', time=0)
# TimePoint(taxi_id=909, name='start shift', time=0)
# TimePoint(taxi_id=857, name='start shift', time=0)
# TimePoint(taxi_id=620, name='start shift', time=0)
# TimePoint(taxi_id=549, name='start shift', time=0)
# TimePoint(taxi_id=537, name='start shift', time=0)
# TimePoint(taxi_id=359, name='start shift', time=0)
# TimePoint(taxi_id=172, name='start shift', time=0)
# TimePoint(taxi_id=357, name='start shift', time=0)
# TimePoint(taxi_id=732, name='start shift', time=0)
# TimePoint(taxi_id=435, name='start shift', time=0)
# TimePoint(taxi_id=637, name='start shift', time=0)
# TimePoint(taxi_id=571, name='start shift', time=0)
# TimePoint(taxi_id=360, name='start shift', time=0)
# TimePoint(taxi_id=969, name='start shift', time=0)
# TimePoint(taxi_id=46, name='start shift', time=0)
# TimePoint(taxi_id=626, name='start shift', time=0)
# TimePoint(taxi_id=490, name='start shift', time=0)
# TimePoint(taxi_id=541, name='start shift', time=0)
# TimePoint(taxi_id=417, name='start shift', time=0)
# TimePoint(taxi_id=928, name='start shift', time=0)
# TimePoint(taxi_id=535, name='start shift', time=0)
# TimePoint(taxi_id=603, name='start shift', time=0)
# TimePoint(taxi_id=211, name='start shift', time=0)
# TimePoint(taxi_id=289, name='start shift', time=0)
# TimePoint(taxi_id=398, name='start shift', time=0)
# TimePoint(taxi_id=766, name='start shift', time=0)
# TimePoint(taxi_id=37, name='start shift', time=0)
# TimePoint(taxi_id=534, name='start shift', time=0)
# TimePoint(taxi_id=730, name='start shift', time=0)
# TimePoint(taxi_id=169, name='start shift', time=0)
# TimePoint(taxi_id=441, name='start shift', time=0)
# TimePoint(taxi_id=640, name='start shift', time=0)
# TimePoint(taxi_id=613, name='start shift', time=0)
# TimePoint(taxi_id=663, name='start shift', time=0)
# TimePoint(taxi_id=187, name='start shift', time=0)
# TimePoint(taxi_id=665, name='start shift', time=0)
# TimePoint(taxi_id=294, name='start shift', time=0)
# TimePoint(taxi_id=340, name='start shift', time=0)
# TimePoint(taxi_id=192, name='start shift', time=0)
# TimePoint(taxi_id=419, name='start shift', time=0)
# TimePoint(taxi_id=411, name='start shift', time=0)
# TimePoint(taxi_id=813, name='start shift', time=0)
# TimePoint(taxi_id=582, name='start shift', time=0)
# TimePoint(taxi_id=51, name='start shift', time=0)
# TimePoint(taxi_id=887, name='start shift', time=0)
# TimePoint(taxi_id=712, name='start shift', time=0)
# TimePoint(taxi_id=967, name='start shift', time=0)
# TimePoint(taxi_id=201, name='start shift', time=0)
# TimePoint(taxi_id=538, name='start shift', time=0)
# TimePoint(taxi_id=830, name='start shift', time=0)
# TimePoint(taxi_id=237, name='start shift', time=0)
# TimePoint(taxi_id=171, name='start shift', time=0)
# TimePoint(taxi_id=199, name='start shift', time=0)
# TimePoint(taxi_id=695, name='start shift', time=0)
# TimePoint(taxi_id=812, name='start shift', time=0)
# TimePoint(taxi_id=263, name='start shift', time=0)
# TimePoint(taxi_id=532, name='start shift', time=0)
# TimePoint(taxi_id=797, name='start shift', time=0)
# TimePoint(taxi_id=748, name='start shift', time=0)
# TimePoint(taxi_id=380, name='pick up', time=0.03333333333333333)
# TimePoint(taxi_id=186, name='pick up', time=0.03333333333333333)
# TimePoint(taxi_id=620, name='pick up', time=0.03333333333333333)
# TimePoint(taxi_id=845, name='pick up', time=0.05)
# TimePoint(taxi_id=636, name='pick up', time=0.05)
# TimePoint(taxi_id=221, name='pick up', time=0.05)
# TimePoint(taxi_id=289, name='pick up', time=0.05)
# TimePoint(taxi_id=51, name='pick up', time=0.05)
# TimePoint(taxi_id=773, name='pick up', time=0.06666666666666667)
# TimePoint(taxi_id=678, name='pick up', time=0.06666666666666667)
# TimePoint(taxi_id=734, name='pick up', time=0.06666666666666667)
# TimePoint(taxi_id=238, name='pick up', time=0.06666666666666667)
# TimePoint(taxi_id=489, name='pick up', time=0.06666666666666667)
# TimePoint(taxi_id=557, name='pick up', time=0.06666666666666667)
# TimePoint(taxi_id=143, name='pick up', time=0.06666666666666667)
# TimePoint(taxi_id=240, name='pick up', time=0.06666666666666667)
# TimePoint(taxi_id=162, name='pick up', time=0.06666666666666667)
# TimePoint(taxi_id=443, name='pick up', time=0.08333333333333333)
# TimePoint(taxi_id=966, name='pick up', time=0.08333333333333333)
# TimePoint(taxi_id=220, name='pick up', time=0.08333333333333333)
# TimePoint(taxi_id=907, name='pick up', time=0.08333333333333333)
# TimePoint(taxi_id=547, name='pick up', time=0.08333333333333333)
# TimePoint(taxi_id=670, name='pick up', time=0.08333333333333333)
# TimePoint(taxi_id=779, name='pick up', time=0.08333333333333333)
# TimePoint(taxi_id=839, name='pick up', time=0.08333333333333333)
# TimePoint(taxi_id=406, name='pick up', time=0.08333333333333333)
# TimePoint(taxi_id=61, name='pick up', time=0.08333333333333333)
# TimePoint(taxi_id=459, name='pick up', time=0.08333333333333333)
# TimePoint(taxi_id=368, name='pick up', time=0.08333333333333333)
# TimePoint(taxi_id=312, name='pick up', time=0.08333333333333333)
# TimePoint(taxi_id=857, name='pick up', time=0.08333333333333333)
# TimePoint(taxi_id=172, name='pick up', time=0.08333333333333333)
# TimePoint(taxi_id=211, name='pick up', time=0.08333333333333333)
# TimePoint(taxi_id=603, name='pick up', time=0.08333333333333333)
# TimePoint(taxi_id=201, name='pick up', time=0.08333333333333333)
# TimePoint(taxi_id=237, name='pick up', time=0.08333333333333333)
# TimePoint(taxi_id=812, name='pick up', time=0.08333333333333333)
# TimePoint(taxi_id=199, name='pick up', time=0.08333333333333333)
# TimePoint(taxi_id=797, name='pick up', time=0.08333333333333333)
# TimePoint(taxi_id=628, name='pick up', time=0.1)
# TimePoint(taxi_id=556, name='pick up', time=0.1)
# TimePoint(taxi_id=283, name='pick up', time=0.1)
# TimePoint(taxi_id=953, name='pick up', time=0.1)
# TimePoint(taxi_id=563, name='pick up', time=0.1)
# TimePoint(taxi_id=491, name='pick up', time=0.1)
# TimePoint(taxi_id=810, name='pick up', time=0.1)
# TimePoint(taxi_id=78, name='pick up', time=0.1)
# TimePoint(taxi_id=899, name='pick up', time=0.1)
# TimePoint(taxi_id=533, name='pick up', time=0.1)
# TimePoint(taxi_id=825, name='pick up', time=0.1)
# TimePoint(taxi_id=617, name='pick up', time=0.1)
# TimePoint(taxi_id=955, name='pick up', time=0.1)
# TimePoint(taxi_id=492, name='pick up', time=0.1)
# TimePoint(taxi_id=514, name='pick up', time=0.1)
# TimePoint(taxi_id=595, name='pick up', time=0.1)
# TimePoint(taxi_id=470, name='pick up', time=0.1)
# TimePoint(taxi_id=381, name='pick up', time=0.1)
# TimePoint(taxi_id=243, name='pick up', time=0.1)
# TimePoint(taxi_id=169, name='pick up', time=0.1)
# TimePoint(taxi_id=663, name='pick up', time=0.1)
# TimePoint(taxi_id=192, name='pick up', time=0.1)
# TimePoint(taxi_id=538, name='pick up', time=0.1)
# TimePoint(taxi_id=498, name='pick up', time=0.11666666666666667)
# TimePoint(taxi_id=515, name='pick up', time=0.11666666666666667)
# TimePoint(taxi_id=84, name='pick up', time=0.11666666666666667)
# TimePoint(taxi_id=132, name='pick up', time=0.11666666666666667)
# TimePoint(taxi_id=367, name='pick up', time=0.11666666666666667)
# TimePoint(taxi_id=57, name='pick up', time=0.11666666666666667)
# TimePoint(taxi_id=439, name='pick up', time=0.11666666666666667)
# TimePoint(taxi_id=642, name='pick up', time=0.11666666666666667)
# TimePoint(taxi_id=952, name='pick up', time=0.11666666666666667)
# TimePoint(taxi_id=972, name='pick up', time=0.11666666666666667)
# TimePoint(taxi_id=930, name='pick up', time=0.11666666666666667)
# TimePoint(taxi_id=588, name='pick up', time=0.11666666666666667)
# TimePoint(taxi_id=503, name='pick up', time=0.11666666666666667)
# TimePoint(taxi_id=920, name='pick up', time=0.11666666666666667)
# TimePoint(taxi_id=671, name='pick up', time=0.11666666666666667)
# TimePoint(taxi_id=606, name='pick up', time=0.11666666666666667)
# TimePoint(taxi_id=357, name='pick up', time=0.11666666666666667)
# TimePoint(taxi_id=369, name='pick up', time=0.11666666666666667)
# TimePoint(taxi_id=813, name='pick up', time=0.11666666666666667)
# TimePoint(taxi_id=830, name='pick up', time=0.11666666666666667)
# TimePoint(taxi_id=532, name='pick up', time=0.11666666666666667)
# TimePoint(taxi_id=748, name='pick up', time=0.11666666666666667)
# TimePoint(taxi_id=775, name='pick up', time=0.13333333333333333)
# TimePoint(taxi_id=971, name='pick up', time=0.13333333333333333)
# TimePoint(taxi_id=483, name='pick up', time=0.13333333333333333)
# TimePoint(taxi_id=248, name='pick up', time=0.13333333333333333)
# TimePoint(taxi_id=658, name='pick up', time=0.13333333333333333)
# TimePoint(taxi_id=745, name='pick up', time=0.13333333333333333)
# TimePoint(taxi_id=755, name='pick up', time=0.13333333333333333)
# TimePoint(taxi_id=66, name='pick up', time=0.13333333333333333)
# TimePoint(taxi_id=316, name='pick up', time=0.13333333333333333)
# TimePoint(taxi_id=68, name='pick up', time=0.13333333333333333)
# TimePoint(taxi_id=297, name='pick up', time=0.13333333333333333)
# TimePoint(taxi_id=2, name='pick up', time=0.13333333333333333)
# TimePoint(taxi_id=586, name='pick up', time=0.13333333333333333)
# TimePoint(taxi_id=660, name='pick up', time=0.13333333333333333)
# TimePoint(taxi_id=631, name='pick up', time=0.13333333333333333)
# TimePoint(taxi_id=154, name='pick up', time=0.13333333333333333)
# TimePoint(taxi_id=23, name='pick up', time=0.13333333333333333)
# TimePoint(taxi_id=849, name='pick up', time=0.13333333333333333)
# TimePoint(taxi_id=994, name='pick up', time=0.13333333333333333)
# TimePoint(taxi_id=94, name='pick up', time=0.13333333333333333)
# TimePoint(taxi_id=343, name='pick up', time=0.13333333333333333)
# TimePoint(taxi_id=844, name='pick up', time=0.13333333333333333)
# TimePoint(taxi_id=6, name='pick up', time=0.13333333333333333)
# TimePoint(taxi_id=62, name='pick up', time=0.13333333333333333)
# TimePoint(taxi_id=410, name='pick up', time=0.13333333333333333)
# TimePoint(taxi_id=421, name='pick up', time=0.13333333333333333)
# TimePoint(taxi_id=351, name='pick up', time=0.13333333333333333)
# TimePoint(taxi_id=395, name='pick up', time=0.13333333333333333)
# TimePoint(taxi_id=580, name='pick up', time=0.13333333333333333)
# TimePoint(taxi_id=275, name='pick up', time=0.13333333333333333)
# TimePoint(taxi_id=683, name='pick up', time=0.13333333333333333)
# TimePoint(taxi_id=519, name='pick up', time=0.13333333333333333)
# TimePoint(taxi_id=39, name='pick up', time=0.13333333333333333)
# TimePoint(taxi_id=378, name='pick up', time=0.13333333333333333)
# TimePoint(taxi_id=90, name='pick up', time=0.13333333333333333)
# TimePoint(taxi_id=571, name='pick up', time=0.13333333333333333)
# TimePoint(taxi_id=637, name='pick up', time=0.13333333333333333)
# TimePoint(taxi_id=359, name='pick up', time=0.13333333333333333)
# TimePoint(taxi_id=128, name='pick up', time=0.13333333333333333)
# TimePoint(taxi_id=766, name='pick up', time=0.13333333333333333)
# TimePoint(taxi_id=294, name='pick up', time=0.13333333333333333)
# TimePoint(taxi_id=534, name='pick up', time=0.13333333333333333)
# TimePoint(taxi_id=187, name='pick up', time=0.13333333333333333)
# TimePoint(taxi_id=263, name='pick up', time=0.13333333333333333)
# TimePoint(taxi_id=912, name='pick up', time=0.15)
# TimePoint(taxi_id=776, name='pick up', time=0.15)
# TimePoint(taxi_id=264, name='pick up', time=0.15)
# TimePoint(taxi_id=888, name='pick up', time=0.15)
# TimePoint(taxi_id=898, name='pick up', time=0.15)
# TimePoint(taxi_id=736, name='pick up', time=0.15)
# TimePoint(taxi_id=487, name='pick up', time=0.15)
# TimePoint(taxi_id=873, name='pick up', time=0.15)
# TimePoint(taxi_id=543, name='pick up', time=0.15)
# TimePoint(taxi_id=346, name='pick up', time=0.15)
# TimePoint(taxi_id=468, name='pick up', time=0.15)
# TimePoint(taxi_id=940, name='pick up', time=0.15)
# TimePoint(taxi_id=846, name='pick up', time=0.15)
# TimePoint(taxi_id=138, name='pick up', time=0.15)
# TimePoint(taxi_id=699, name='pick up', time=0.15)
# TimePoint(taxi_id=647, name='pick up', time=0.15)
# TimePoint(taxi_id=698, name='pick up', time=0.15)
# TimePoint(taxi_id=156, name='pick up', time=0.15)
# TimePoint(taxi_id=764, name='pick up', time=0.15)
# TimePoint(taxi_id=450, name='pick up', time=0.15)
# TimePoint(taxi_id=429, name='pick up', time=0.15)
# TimePoint(taxi_id=214, name='pick up', time=0.15)
# TimePoint(taxi_id=435, name='pick up', time=0.15)
# TimePoint(taxi_id=537, name='pick up', time=0.15)
# TimePoint(taxi_id=411, name='pick up', time=0.15)
# TimePoint(taxi_id=582, name='pick up', time=0.15)
# TimePoint(taxi_id=967, name='pick up', time=0.15)
# TimePoint(taxi_id=654, name='pick up', time=0.16666666666666666)
# TimePoint(taxi_id=270, name='pick up', time=0.16666666666666666)
# TimePoint(taxi_id=164, name='pick up', time=0.16666666666666666)
# TimePoint(taxi_id=254, name='pick up', time=0.16666666666666666)
# TimePoint(taxi_id=505, name='pick up', time=0.16666666666666666)
# TimePoint(taxi_id=816, name='pick up', time=0.16666666666666666)
# TimePoint(taxi_id=209, name='pick up', time=0.16666666666666666)
# TimePoint(taxi_id=803, name='pick up', time=0.16666666666666666)
# TimePoint(taxi_id=574, name='pick up', time=0.16666666666666666)
# TimePoint(taxi_id=919, name='pick up', time=0.16666666666666666)
# TimePoint(taxi_id=31, name='pick up', time=0.16666666666666666)
# TimePoint(taxi_id=973, name='pick up', time=0.16666666666666666)
# TimePoint(taxi_id=987, name='pick up', time=0.16666666666666666)
# TimePoint(taxi_id=424, name='pick up', time=0.16666666666666666)
# TimePoint(taxi_id=894, name='pick up', time=0.16666666666666666)
# TimePoint(taxi_id=566, name='pick up', time=0.16666666666666666)
# TimePoint(taxi_id=604, name='pick up', time=0.16666666666666666)
# TimePoint(taxi_id=194, name='pick up', time=0.16666666666666666)
# TimePoint(taxi_id=929, name='pick up', time=0.16666666666666666)
# TimePoint(taxi_id=305, name='pick up', time=0.16666666666666666)
# TimePoint(taxi_id=384, name='pick up', time=0.16666666666666666)
# TimePoint(taxi_id=800, name='pick up', time=0.16666666666666666)
# TimePoint(taxi_id=149, name='pick up', time=0.16666666666666666)
# TimePoint(taxi_id=917, name='pick up', time=0.16666666666666666)
# TimePoint(taxi_id=548, name='pick up', time=0.16666666666666666)
# TimePoint(taxi_id=909, name='pick up', time=0.16666666666666666)
# TimePoint(taxi_id=732, name='pick up', time=0.16666666666666666)
# TimePoint(taxi_id=360, name='pick up', time=0.16666666666666666)
# TimePoint(taxi_id=626, name='pick up', time=0.16666666666666666)
# TimePoint(taxi_id=541, name='pick up', time=0.16666666666666666)
# TimePoint(taxi_id=417, name='pick up', time=0.16666666666666666)
# TimePoint(taxi_id=535, name='pick up', time=0.16666666666666666)
# TimePoint(taxi_id=887, name='pick up', time=0.16666666666666666)
# TimePoint(taxi_id=695, name='pick up', time=0.16666666666666666)
# TimePoint(taxi_id=163, name='pick up', time=0.18333333333333332)
# TimePoint(taxi_id=170, name='pick up', time=0.18333333333333332)
# TimePoint(taxi_id=231, name='pick up', time=0.18333333333333332)
# TimePoint(taxi_id=728, name='pick up', time=0.18333333333333332)
# TimePoint(taxi_id=826, name='pick up', time=0.18333333333333332)
# TimePoint(taxi_id=353, name='pick up', time=0.18333333333333332)
# TimePoint(taxi_id=89, name='pick up', time=0.18333333333333332)
# TimePoint(taxi_id=133, name='pick up', time=0.18333333333333332)
# TimePoint(taxi_id=437, name='pick up', time=0.18333333333333332)
# TimePoint(taxi_id=49, name='pick up', time=0.18333333333333332)
# TimePoint(taxi_id=329, name='pick up', time=0.18333333333333332)
# TimePoint(taxi_id=711, name='pick up', time=0.18333333333333332)
# TimePoint(taxi_id=306, name='pick up', time=0.18333333333333332)
# TimePoint(taxi_id=327, name='pick up', time=0.18333333333333332)
# TimePoint(taxi_id=315, name='pick up', time=0.18333333333333332)
# TimePoint(taxi_id=762, name='pick up', time=0.18333333333333332)
# TimePoint(taxi_id=497, name='pick up', time=0.18333333333333332)
# TimePoint(taxi_id=46, name='pick up', time=0.18333333333333332)
# TimePoint(taxi_id=928, name='pick up', time=0.18333333333333332)
# TimePoint(taxi_id=441, name='pick up', time=0.18333333333333332)
# TimePoint(taxi_id=340, name='pick up', time=0.18333333333333332)
# TimePoint(taxi_id=171, name='pick up', time=0.18333333333333332)
# TimePoint(taxi_id=338, name='pick up', time=0.2)
# TimePoint(taxi_id=322, name='pick up', time=0.2)
# TimePoint(taxi_id=573, name='pick up', time=0.2)
# TimePoint(taxi_id=129, name='pick up', time=0.2)
# TimePoint(taxi_id=758, name='pick up', time=0.2)
# TimePoint(taxi_id=272, name='pick up', time=0.2)
# TimePoint(taxi_id=756, name='pick up', time=0.2)
# TimePoint(taxi_id=549, name='pick up', time=0.2)
# TimePoint(taxi_id=969, name='pick up', time=0.2)
# TimePoint(taxi_id=613, name='pick up', time=0.2)
# TimePoint(taxi_id=730, name='pick up', time=0.2)
# TimePoint(taxi_id=342, name='pick up', time=0.21666666666666667)
# TimePoint(taxi_id=17, name='pick up', time=0.21666666666666667)
# TimePoint(taxi_id=26, name='pick up', time=0.21666666666666667)
# TimePoint(taxi_id=752, name='pick up', time=0.21666666666666667)
# TimePoint(taxi_id=717, name='pick up', time=0.21666666666666667)
# TimePoint(taxi_id=685, name='pick up', time=0.21666666666666667)
# TimePoint(taxi_id=236, name='pick up', time=0.21666666666666667)
# TimePoint(taxi_id=176, name='pick up', time=0.21666666666666667)
# TimePoint(taxi_id=1, name='pick up', time=0.21666666666666667)
# TimePoint(taxi_id=861, name='pick up', time=0.21666666666666667)
# TimePoint(taxi_id=153, name='pick up', time=0.21666666666666667)
# TimePoint(taxi_id=602, name='pick up', time=0.21666666666666667)
# TimePoint(taxi_id=37, name='pick up', time=0.21666666666666667)
# TimePoint(taxi_id=862, name='pick up', time=0.23333333333333334)
# TimePoint(taxi_id=54, name='pick up', time=0.23333333333333334)
# TimePoint(taxi_id=490, name='pick up', time=0.23333333333333334)
# TimePoint(taxi_id=398, name='pick up', time=0.23333333333333334)
# TimePoint(taxi_id=640, name='pick up', time=0.23333333333333334)
# TimePoint(taxi_id=665, name='pick up', time=0.23333333333333334)
# TimePoint(taxi_id=419, name='pick up', time=0.23333333333333334)
# TimePoint(taxi_id=292, name='pick up', time=0.25)
# TimePoint(taxi_id=712, name='pick up', time=0.25)
# TimePoint(taxi_id=197, name='pick up', time=0.26666666666666666)
# TimePoint(taxi_id=121, name='pick up', time=0.3)
# TimePoint(taxi_id=557, name='drop off', time=0.6333333333333333)
# TimePoint(taxi_id=972, name='drop off', time=0.6333333333333334)
# TimePoint(taxi_id=368, name='drop off', time=0.6333333333333334)
# TimePoint(taxi_id=803, name='drop off', time=0.6666666666666666)
# TimePoint(taxi_id=489, name='drop off', time=0.6833333333333333)
# TimePoint(taxi_id=143, name='drop off', time=0.6833333333333333)
# TimePoint(taxi_id=972, name='pick up', time=0.7000000000000001)
# TimePoint(taxi_id=846, name='drop off', time=0.7000000000000001)
# TimePoint(taxi_id=380, name='drop off', time=0.7166666666666667)
# TimePoint(taxi_id=61, name='drop off', time=0.7333333333333334)
# TimePoint(taxi_id=172, name='drop off', time=0.7333333333333334)
# TimePoint(taxi_id=631, name='drop off', time=0.75)
# TimePoint(taxi_id=437, name='drop off', time=0.75)
# TimePoint(taxi_id=240, name='drop off', time=0.75)
# TimePoint(taxi_id=678, name='drop off', time=0.7666666666666666)
# TimePoint(taxi_id=162, name='drop off', time=0.7666666666666666)
# TimePoint(taxi_id=595, name='drop off', time=0.7666666666666666)
# TimePoint(taxi_id=243, name='drop off', time=0.7666666666666666)
# TimePoint(taxi_id=776, name='drop off', time=0.7666666666666667)
# TimePoint(taxi_id=588, name='drop off', time=0.7666666666666667)
# TimePoint(taxi_id=532, name='drop off', time=0.7666666666666667)
# TimePoint(taxi_id=748, name='drop off', time=0.7666666666666667)
# TimePoint(taxi_id=238, name='drop off', time=0.7833333333333333)
# TimePoint(taxi_id=57, name='drop off', time=0.7833333333333333)
# TimePoint(taxi_id=297, name='drop off', time=0.7833333333333333)
# TimePoint(taxi_id=23, name='drop off', time=0.7833333333333333)
# TimePoint(taxi_id=899, name='drop off', time=0.7833333333333333)
# TimePoint(taxi_id=955, name='drop off', time=0.7833333333333333)
# TimePoint(taxi_id=489, name='pick up', time=0.7833333333333333)
# TimePoint(taxi_id=406, name='drop off', time=0.7833333333333333)
# TimePoint(taxi_id=514, name='drop off', time=0.7833333333333333)
# TimePoint(taxi_id=169, name='drop off', time=0.7833333333333333)
# TimePoint(taxi_id=201, name='drop off', time=0.7833333333333333)
# TimePoint(taxi_id=369, name='drop off', time=0.7833333333333333)
# TimePoint(taxi_id=755, name='drop off', time=0.7999999999999999)
# TimePoint(taxi_id=2, name='drop off', time=0.7999999999999999)
# TimePoint(taxi_id=557, name='pick up', time=0.7999999999999999)
# TimePoint(taxi_id=384, name='drop off', time=0.7999999999999999)
# TimePoint(taxi_id=940, name='drop off', time=0.8)
# TimePoint(taxi_id=779, name='drop off', time=0.8)
# TimePoint(taxi_id=143, name='pick up', time=0.8)
# TimePoint(taxi_id=620, name='drop off', time=0.8)
# TimePoint(taxi_id=736, name='drop off', time=0.8166666666666667)
# TimePoint(taxi_id=752, name='drop off', time=0.8166666666666667)
# TimePoint(taxi_id=803, name='pick up', time=0.8166666666666667)
# TimePoint(taxi_id=586, name='drop off', time=0.8166666666666667)
# TimePoint(taxi_id=439, name='drop off', time=0.8166666666666667)
# TimePoint(taxi_id=839, name='drop off', time=0.8166666666666667)
# TimePoint(taxi_id=237, name='drop off', time=0.8166666666666667)
# TimePoint(taxi_id=221, name='drop off', time=0.8166666666666668)
# TimePoint(taxi_id=31, name='drop off', time=0.8333333333333333)
# TimePoint(taxi_id=845, name='drop off', time=0.8333333333333334)
# TimePoint(taxi_id=826, name='drop off', time=0.8333333333333334)
# TimePoint(taxi_id=156, name='drop off', time=0.8333333333333334)
# TimePoint(taxi_id=602, name='drop off', time=0.8333333333333334)
# TimePoint(taxi_id=830, name='drop off', time=0.8333333333333334)
# TimePoint(taxi_id=368, name='pick up', time=0.8333333333333335)
# TimePoint(taxi_id=66, name='drop off', time=0.85)
# TimePoint(taxi_id=586, name='pick up', time=0.85)
# TimePoint(taxi_id=236, name='drop off', time=0.85)
# TimePoint(taxi_id=49, name='drop off', time=0.85)
# TimePoint(taxi_id=240, name='pick up', time=0.85)
# TimePoint(taxi_id=138, name='drop off', time=0.85)
# TimePoint(taxi_id=275, name='drop off', time=0.85)
# TimePoint(taxi_id=917, name='drop off', time=0.85)
# TimePoint(taxi_id=443, name='drop off', time=0.8500000000000001)
# TimePoint(taxi_id=670, name='drop off', time=0.8500000000000001)
# TimePoint(taxi_id=172, name='pick up', time=0.8500000000000001)
# TimePoint(taxi_id=211, name='drop off', time=0.8500000000000001)
# TimePoint(taxi_id=270, name='drop off', time=0.8666666666666666)
# TimePoint(taxi_id=678, name='pick up', time=0.8666666666666666)
# TimePoint(taxi_id=164, name='drop off', time=0.8666666666666666)
# TimePoint(taxi_id=68, name='drop off', time=0.8666666666666666)
# TimePoint(taxi_id=987, name='drop off', time=0.8666666666666666)
# TimePoint(taxi_id=566, name='drop off', time=0.8666666666666666)
# TimePoint(taxi_id=384, name='pick up', time=0.8666666666666666)
# TimePoint(taxi_id=683, name='drop off', time=0.8666666666666666)
# TimePoint(taxi_id=39, name='drop off', time=0.8666666666666666)
# TimePoint(taxi_id=766, name='drop off', time=0.8666666666666666)
# TimePoint(taxi_id=263, name='drop off', time=0.8666666666666666)
# TimePoint(taxi_id=966, name='drop off', time=0.8666666666666667)
# TimePoint(taxi_id=631, name='pick up', time=0.8666666666666667)
# TimePoint(taxi_id=437, name='pick up', time=0.8666666666666667)
# TimePoint(taxi_id=846, name='pick up', time=0.8666666666666667)
# TimePoint(taxi_id=588, name='pick up', time=0.8666666666666667)
# TimePoint(taxi_id=312, name='drop off', time=0.8666666666666667)
# TimePoint(taxi_id=969, name='drop off', time=0.8666666666666667)
# TimePoint(taxi_id=888, name='drop off', time=0.8833333333333333)
# TimePoint(taxi_id=658, name='drop off', time=0.8833333333333333)
# TimePoint(taxi_id=380, name='pick up', time=0.8833333333333333)
# TimePoint(taxi_id=919, name='drop off', time=0.8833333333333333)
# TimePoint(taxi_id=660, name='drop off', time=0.8833333333333333)
# TimePoint(taxi_id=78, name='drop off', time=0.8833333333333333)
# TimePoint(taxi_id=887, name='drop off', time=0.8833333333333333)
# TimePoint(taxi_id=547, name='drop off', time=0.8833333333333334)
# TimePoint(taxi_id=952, name='drop off', time=0.8833333333333334)
# TimePoint(taxi_id=357, name='drop off', time=0.8833333333333334)
# TimePoint(taxi_id=31, name='pick up', time=0.8999999999999999)
# TimePoint(taxi_id=162, name='pick up', time=0.8999999999999999)
# TimePoint(taxi_id=776, name='pick up', time=0.9)
# TimePoint(taxi_id=483, name='drop off', time=0.9)
# TimePoint(taxi_id=283, name='drop off', time=0.9)
# TimePoint(taxi_id=297, name='pick up', time=0.9)
# TimePoint(taxi_id=642, name='drop off', time=0.9)
# TimePoint(taxi_id=176, name='drop off', time=0.9)
# TimePoint(taxi_id=940, name='pick up', time=0.9)
# TimePoint(taxi_id=61, name='pick up', time=0.9)
# TimePoint(taxi_id=711, name='drop off', time=0.9)
# TimePoint(taxi_id=351, name='drop off', time=0.9)
# TimePoint(taxi_id=519, name='drop off', time=0.9)
# TimePoint(taxi_id=663, name='drop off', time=0.9)
# TimePoint(taxi_id=369, name='pick up', time=0.9)
# TimePoint(taxi_id=221, name='pick up', time=0.9000000000000001)
# TimePoint(taxi_id=745, name='drop off', time=0.9166666666666666)
# TimePoint(taxi_id=755, name='pick up', time=0.9166666666666666)
# TimePoint(taxi_id=953, name='drop off', time=0.9166666666666666)
# TimePoint(taxi_id=752, name='pick up', time=0.9166666666666666)
# TimePoint(taxi_id=353, name='drop off', time=0.9166666666666666)
# TimePoint(taxi_id=685, name='drop off', time=0.9166666666666666)
# TimePoint(taxi_id=154, name='drop off', time=0.9166666666666666)
# TimePoint(taxi_id=23, name='pick up', time=0.9166666666666666)
# TimePoint(taxi_id=849, name='drop off', time=0.9166666666666666)
# TimePoint(taxi_id=899, name='pick up', time=0.9166666666666666)
# TimePoint(taxi_id=994, name='drop off', time=0.9166666666666666)
# TimePoint(taxi_id=381, name='drop off', time=0.9166666666666666)
# TimePoint(taxi_id=417, name='drop off', time=0.9166666666666666)
# TimePoint(taxi_id=340, name='drop off', time=0.9166666666666666)
# TimePoint(taxi_id=498, name='drop off', time=0.9166666666666667)
# TimePoint(taxi_id=537, name='drop off', time=0.9166666666666667)
# TimePoint(taxi_id=411, name='drop off', time=0.9166666666666667)
# TimePoint(taxi_id=797, name='drop off', time=0.9166666666666667)
# TimePoint(taxi_id=566, name='pick up', time=0.9333333333333332)
# TimePoint(taxi_id=775, name='drop off', time=0.9333333333333333)
# TimePoint(taxi_id=912, name='drop off', time=0.9333333333333333)
# TimePoint(taxi_id=773, name='drop off', time=0.9333333333333333)
# TimePoint(taxi_id=574, name='drop off', time=0.9333333333333333)
# TimePoint(taxi_id=810, name='drop off', time=0.9333333333333333)
# TimePoint(taxi_id=439, name='pick up', time=0.9333333333333333)
# TimePoint(taxi_id=503, name='drop off', time=0.9333333333333333)
# TimePoint(taxi_id=305, name='drop off', time=0.9333333333333333)
# TimePoint(taxi_id=406, name='pick up', time=0.9333333333333333)
# TimePoint(taxi_id=62, name='drop off', time=0.9333333333333333)
# TimePoint(taxi_id=421, name='drop off', time=0.9333333333333333)
# TimePoint(taxi_id=764, name='drop off', time=0.9333333333333333)
# TimePoint(taxi_id=920, name='drop off', time=0.9333333333333333)
# TimePoint(taxi_id=149, name='drop off', time=0.9333333333333333)
# TimePoint(taxi_id=275, name='pick up', time=0.9333333333333333)
# TimePoint(taxi_id=128, name='drop off', time=0.9333333333333333)
# TimePoint(taxi_id=360, name='drop off', time=0.9333333333333333)
# TimePoint(taxi_id=730, name='drop off', time=0.9333333333333333)
# TimePoint(taxi_id=192, name='drop off', time=0.9333333333333333)
# TimePoint(taxi_id=695, name='drop off', time=0.9333333333333333)
# TimePoint(taxi_id=532, name='pick up', time=0.9333333333333333)
# TimePoint(taxi_id=952, name='pick up', time=0.9333333333333335)
# TimePoint(taxi_id=971, name='drop off', time=0.95)
# TimePoint(taxi_id=556, name='drop off', time=0.95)
# TimePoint(taxi_id=68, name='pick up', time=0.95)
# TimePoint(taxi_id=57, name='pick up', time=0.95)
# TimePoint(taxi_id=2, name='pick up', time=0.95)
# TimePoint(taxi_id=343, name='drop off', time=0.95)
# TimePoint(taxi_id=955, name='pick up', time=0.95)
# TimePoint(taxi_id=595, name='pick up', time=0.95)
# TimePoint(taxi_id=470, name='drop off', time=0.95)
# TimePoint(taxi_id=243, name='pick up', time=0.95)
# TimePoint(taxi_id=549, name='drop off', time=0.95)
# TimePoint(taxi_id=237, name='pick up', time=0.95)
# TimePoint(taxi_id=220, name='drop off', time=0.9500000000000001)
# TimePoint(taxi_id=907, name='drop off', time=0.9500000000000001)
# TimePoint(taxi_id=515, name='drop off', time=0.9500000000000001)
# TimePoint(taxi_id=346, name='drop off', time=0.9500000000000001)
# TimePoint(taxi_id=647, name='drop off', time=0.9500000000000001)
# TimePoint(taxi_id=497, name='drop off', time=0.9500000000000001)
# TimePoint(taxi_id=969, name='pick up', time=0.9500000000000001)
# TimePoint(taxi_id=813, name='drop off', time=0.9500000000000001)
# TimePoint(taxi_id=748, name='pick up', time=0.9500000000000001)
# TimePoint(taxi_id=966, name='pick up', time=0.9666666666666667)
# TimePoint(taxi_id=628, name='drop off', time=0.9666666666666667)
# TimePoint(taxi_id=254, name='drop off', time=0.9666666666666667)
# TimePoint(taxi_id=238, name='pick up', time=0.9666666666666667)
# TimePoint(taxi_id=826, name='pick up', time=0.9666666666666667)
# TimePoint(taxi_id=491, name='drop off', time=0.9666666666666667)
# TimePoint(taxi_id=642, name='pick up', time=0.9666666666666667)
# TimePoint(taxi_id=424, name='drop off', time=0.9666666666666667)
# TimePoint(taxi_id=492, name='drop off', time=0.9666666666666667)
# TimePoint(taxi_id=604, name='drop off', time=0.9666666666666667)
# TimePoint(taxi_id=186, name='drop off', time=0.9666666666666667)
# TimePoint(taxi_id=930, name='drop off', time=0.9666666666666667)
# TimePoint(taxi_id=779, name='pick up', time=0.9666666666666667)
# TimePoint(taxi_id=636, name='drop off', time=0.9666666666666667)
# TimePoint(taxi_id=514, name='pick up', time=0.9666666666666667)
# TimePoint(taxi_id=410, name='drop off', time=0.9666666666666667)
# TimePoint(taxi_id=315, name='drop off', time=0.9666666666666667)
# TimePoint(taxi_id=620, name='pick up', time=0.9666666666666667)
# TimePoint(taxi_id=435, name='drop off', time=0.9666666666666667)
# TimePoint(taxi_id=169, name='pick up', time=0.9666666666666667)
# TimePoint(taxi_id=663, name='pick up', time=0.9666666666666667)
# TimePoint(taxi_id=187, name='drop off', time=0.9666666666666667)
# TimePoint(taxi_id=201, name='pick up', time=0.9666666666666667)
# TimePoint(taxi_id=211, name='pick up', time=0.9666666666666668)
# TimePoint(taxi_id=654, name='drop off', time=0.9833333333333333)
# TimePoint(taxi_id=816, name='drop off', time=0.9833333333333333)
# TimePoint(taxi_id=209, name='drop off', time=0.9833333333333333)
# TimePoint(taxi_id=849, name='pick up', time=0.9833333333333333)
# TimePoint(taxi_id=973, name='drop off', time=0.9833333333333333)
# TimePoint(taxi_id=94, name='drop off', time=0.9833333333333333)
# TimePoint(taxi_id=138, name='pick up', time=0.9833333333333333)
# TimePoint(taxi_id=929, name='drop off', time=0.9833333333333333)
# TimePoint(taxi_id=683, name='pick up', time=0.9833333333333333)
# TimePoint(taxi_id=39, name='pick up', time=0.9833333333333333)
# TimePoint(taxi_id=378, name='drop off', time=0.9833333333333333)
# TimePoint(taxi_id=909, name='drop off', time=0.9833333333333333)
# TimePoint(taxi_id=534, name='drop off', time=0.9833333333333333)
# TimePoint(taxi_id=538, name='drop off', time=0.9833333333333333)
# TimePoint(taxi_id=443, name='pick up', time=0.9833333333333334)
# TimePoint(taxi_id=170, name='drop off', time=0.9833333333333334)
# TimePoint(taxi_id=84, name='drop off', time=0.9833333333333334)
# TimePoint(taxi_id=367, name='drop off', time=0.9833333333333334)
# TimePoint(taxi_id=606, name='drop off', time=0.9833333333333334)
# TimePoint(taxi_id=602, name='pick up', time=0.9833333333333334)
# TimePoint(taxi_id=756, name='drop off', time=0.9833333333333334)
# TimePoint(taxi_id=289, name='drop off', time=0.9833333333333334)
# TimePoint(taxi_id=51, name='drop off', time=0.9833333333333334)
# TimePoint(taxi_id=830, name='pick up', time=0.9833333333333334)
# TimePoint(taxi_id=164, name='pick up', time=0.9999999999999999)
# TimePoint(taxi_id=734, name='drop off', time=1.0)
# TimePoint(taxi_id=658, name='pick up', time=1.0)
# TimePoint(taxi_id=26, name='drop off', time=1.0)
# TimePoint(taxi_id=89, name='drop off', time=1.0)
# TimePoint(taxi_id=78, name='pick up', time=1.0)
# TimePoint(taxi_id=236, name='pick up', time=1.0)
# TimePoint(taxi_id=699, name='drop off', time=1.0)
# TimePoint(taxi_id=839, name='pick up', time=1.0)
# TimePoint(taxi_id=395, name='drop off', time=1.0)
# TimePoint(taxi_id=149, name='pick up', time=1.0)
# TimePoint(taxi_id=450, name='drop off', time=1.0)
# TimePoint(taxi_id=312, name='pick up', time=1.0)
# TimePoint(taxi_id=732, name='drop off', time=1.0)
# TimePoint(taxi_id=128, name='pick up', time=1.0)
# TimePoint(taxi_id=441, name='drop off', time=1.0)
# TimePoint(taxi_id=199, name='drop off', time=1.0)
# TimePoint(taxi_id=628, name='pick up', time=1.0166666666666666)
# TimePoint(taxi_id=66, name='pick up', time=1.0166666666666666)
# TimePoint(taxi_id=132, name='drop off', time=1.0166666666666666)
# TimePoint(taxi_id=919, name='pick up', time=1.0166666666666666)
# TimePoint(taxi_id=987, name='pick up', time=1.0166666666666666)
# TimePoint(taxi_id=894, name='drop off', time=1.0166666666666666)
# TimePoint(taxi_id=329, name='drop off', time=1.0166666666666666)
# TimePoint(taxi_id=468, name='drop off', time=1.0166666666666666)
# TimePoint(taxi_id=1, name='drop off', time=1.0166666666666666)
# TimePoint(taxi_id=617, name='drop off', time=1.0166666666666666)
# TimePoint(taxi_id=194, name='drop off', time=1.0166666666666666)
# TimePoint(taxi_id=698, name='drop off', time=1.0166666666666666)
# TimePoint(taxi_id=421, name='pick up', time=1.0166666666666666)
# TimePoint(taxi_id=417, name='pick up', time=1.0166666666666666)
# TimePoint(taxi_id=547, name='pick up', time=1.0166666666666668)
# TimePoint(taxi_id=357, name='pick up', time=1.0166666666666668)
# TimePoint(taxi_id=813, name='pick up', time=1.0166666666666668)
# TimePoint(taxi_id=971, name='pick up', time=1.0333333333333332)
# TimePoint(taxi_id=270, name='pick up', time=1.0333333333333332)
# TimePoint(taxi_id=953, name='pick up', time=1.0333333333333332)
# TimePoint(taxi_id=329, name='pick up', time=1.0333333333333332)
# TimePoint(taxi_id=327, name='drop off', time=1.0333333333333332)
# TimePoint(taxi_id=470, name='pick up', time=1.0333333333333332)
# TimePoint(taxi_id=549, name='pick up', time=1.0333333333333332)
# TimePoint(taxi_id=603, name='drop off', time=1.0333333333333332)
# TimePoint(taxi_id=582, name='drop off', time=1.0333333333333332)
# TimePoint(taxi_id=967, name='drop off', time=1.0333333333333332)
# TimePoint(taxi_id=505, name='drop off', time=1.0333333333333334)
# TimePoint(taxi_id=424, name='pick up', time=1.0333333333333334)
# TimePoint(taxi_id=825, name='drop off', time=1.0333333333333334)
# TimePoint(taxi_id=503, name='pick up', time=1.0333333333333334)
# TimePoint(taxi_id=156, name='pick up', time=1.0333333333333334)
# TimePoint(taxi_id=537, name='pick up', time=1.0333333333333334)
# TimePoint(taxi_id=535, name='drop off', time=1.0333333333333334)
# TimePoint(taxi_id=640, name='drop off', time=1.0333333333333334)
# TimePoint(taxi_id=263, name='pick up', time=1.0499999999999998)
# TimePoint(taxi_id=163, name='drop off', time=1.05)
# TimePoint(taxi_id=912, name='pick up', time=1.05)
# TimePoint(taxi_id=220, name='pick up', time=1.05)
# TimePoint(taxi_id=248, name='drop off', time=1.05)
# TimePoint(taxi_id=898, name='drop off', time=1.05)
# TimePoint(taxi_id=736, name='pick up', time=1.05)
# TimePoint(taxi_id=231, name='drop off', time=1.05)
# TimePoint(taxi_id=745, name='pick up', time=1.05)
# TimePoint(taxi_id=670, name='pick up', time=1.05)
# TimePoint(taxi_id=717, name='drop off', time=1.05)
# TimePoint(taxi_id=154, name='pick up', time=1.05)
# TimePoint(taxi_id=894, name='pick up', time=1.05)
# TimePoint(taxi_id=533, name='drop off', time=1.05)
# TimePoint(taxi_id=6, name='drop off', time=1.05)
# TimePoint(taxi_id=580, name='drop off', time=1.05)
# TimePoint(taxi_id=762, name='drop off', time=1.05)
# TimePoint(taxi_id=90, name='drop off', time=1.05)
# TimePoint(taxi_id=340, name='pick up', time=1.05)
# TimePoint(taxi_id=51, name='pick up', time=1.05)
# TimePoint(taxi_id=695, name='pick up', time=1.05)
# TimePoint(taxi_id=812, name='drop off', time=1.05)
# TimePoint(taxi_id=171, name='drop off', time=1.05)
# TimePoint(taxi_id=483, name='pick up', time=1.0666666666666667)
# TimePoint(taxi_id=845, name='pick up', time=1.0666666666666667)
# TimePoint(taxi_id=342, name='drop off', time=1.0666666666666667)
# TimePoint(taxi_id=888, name='pick up', time=1.0666666666666667)
# TimePoint(taxi_id=283, name='pick up', time=1.0666666666666667)
# TimePoint(taxi_id=254, name='pick up', time=1.0666666666666667)
# TimePoint(taxi_id=563, name='drop off', time=1.0666666666666667)
# TimePoint(taxi_id=316, name='drop off', time=1.0666666666666667)
# TimePoint(taxi_id=660, name='pick up', time=1.0666666666666667)
# TimePoint(taxi_id=685, name='pick up', time=1.0666666666666667)
# TimePoint(taxi_id=468, name='pick up', time=1.0666666666666667)
# TimePoint(taxi_id=492, name='pick up', time=1.0666666666666667)
# TimePoint(taxi_id=711, name='pick up', time=1.0666666666666667)
# TimePoint(taxi_id=351, name='pick up', time=1.0666666666666667)
# TimePoint(taxi_id=764, name='pick up', time=1.0666666666666667)
# TimePoint(taxi_id=459, name='drop off', time=1.0666666666666667)
# TimePoint(taxi_id=800, name='drop off', time=1.0666666666666667)
# TimePoint(taxi_id=920, name='pick up', time=1.0666666666666667)
# TimePoint(taxi_id=519, name='pick up', time=1.0666666666666667)
# TimePoint(taxi_id=917, name='pick up', time=1.0666666666666667)
# TimePoint(taxi_id=637, name='drop off', time=1.0666666666666667)
# TimePoint(taxi_id=360, name='pick up', time=1.0666666666666667)
# TimePoint(taxi_id=541, name='drop off', time=1.0666666666666667)
# TimePoint(taxi_id=398, name='drop off', time=1.0666666666666667)
# TimePoint(taxi_id=192, name='pick up', time=1.0666666666666667)
# TimePoint(taxi_id=411, name='pick up', time=1.0666666666666667)
# TimePoint(taxi_id=187, name='pick up', time=1.0666666666666667)
# TimePoint(taxi_id=574, name='pick up', time=1.0833333333333333)
# TimePoint(taxi_id=810, name='pick up', time=1.0833333333333333)
# TimePoint(taxi_id=133, name='drop off', time=1.0833333333333333)
# TimePoint(taxi_id=176, name='pick up', time=1.0833333333333333)
# TimePoint(taxi_id=994, name='pick up', time=1.0833333333333333)
# TimePoint(taxi_id=49, name='pick up', time=1.0833333333333333)
# TimePoint(taxi_id=186, name='pick up', time=1.0833333333333333)
# TimePoint(taxi_id=395, name='pick up', time=1.0833333333333333)
# TimePoint(taxi_id=381, name='pick up', time=1.0833333333333333)
# TimePoint(taxi_id=435, name='pick up', time=1.0833333333333333)
# TimePoint(taxi_id=46, name='drop off', time=1.0833333333333333)
# ...
# TimePoint(taxi_id=317, name='end shift', time=23.533333333333328)
# TimePoint(taxi_id=889, name='drop off', time=23.53333333333333)
# TimePoint(taxi_id=504, name='drop off', time=23.53333333333333)
# TimePoint(taxi_id=701, name='pick up', time=23.53333333333333)
# TimePoint(taxi_id=278, name='pick up', time=23.53333333333333)
# TimePoint(taxi_id=747, name='drop off', time=23.533333333333335)
# TimePoint(taxi_id=4, name='drop off', time=23.533333333333335)
# TimePoint(taxi_id=400, name='pick up', time=23.533333333333335)
# TimePoint(taxi_id=610, name='drop off', time=23.533333333333335)
# TimePoint(taxi_id=123, name='pick up', time=23.53333333333334)
# TimePoint(taxi_id=205, name='end shift', time=23.53333333333334)
# TimePoint(taxi_id=895, name='drop off', time=23.533333333333342)
# TimePoint(taxi_id=700, name='drop off', time=23.549999999999997)
# TimePoint(taxi_id=65, name='pick up', time=23.55)
# TimePoint(taxi_id=116, name='pick up', time=23.550000000000004)
# TimePoint(taxi_id=868, name='drop off', time=23.550000000000004)
# TimePoint(taxi_id=829, name='pick up', time=23.550000000000004)
# TimePoint(taxi_id=444, name='drop off', time=23.550000000000004)
# TimePoint(taxi_id=600, name='pick up', time=23.550000000000004)
# TimePoint(taxi_id=616, name='drop off', time=23.566666666666663)
# TimePoint(taxi_id=770, name='drop off', time=23.566666666666666)
# TimePoint(taxi_id=235, name='pick up', time=23.566666666666666)
# TimePoint(taxi_id=366, name='pick up', time=23.566666666666666)
# TimePoint(taxi_id=863, name='drop off', time=23.56666666666667)
# TimePoint(taxi_id=540, name='drop off', time=23.56666666666667)
# TimePoint(taxi_id=924, name='drop off', time=23.566666666666674)
# TimePoint(taxi_id=668, name='end shift', time=23.566666666666674)
# TimePoint(taxi_id=686, name='drop off', time=23.566666666666674)
# TimePoint(taxi_id=614, name='drop off', time=23.566666666666677)
# TimePoint(taxi_id=345, name='end shift', time=23.566666666666677)
# TimePoint(taxi_id=326, name='pick up', time=23.566666666666677)
# TimePoint(taxi_id=334, name='drop off', time=23.566666666666677)
# TimePoint(taxi_id=833, name='drop off', time=23.566666666666677)
# TimePoint(taxi_id=978, name='drop off', time=23.58333333333333)
# TimePoint(taxi_id=510, name='pick up', time=23.58333333333333)
# TimePoint(taxi_id=540, name='pick up', time=23.583333333333336)
# TimePoint(taxi_id=718, name='end shift', time=23.583333333333336)
# TimePoint(taxi_id=737, name='pick up', time=23.583333333333336)
# TimePoint(taxi_id=29, name='drop off', time=23.583333333333336)
# TimePoint(taxi_id=307, name='drop off', time=23.58333333333334)
# TimePoint(taxi_id=693, name='drop off', time=23.58333333333334)
# TimePoint(taxi_id=686, name='pick up', time=23.58333333333334)
# TimePoint(taxi_id=796, name='drop off', time=23.583333333333346)
# TimePoint(taxi_id=69, name='drop off', time=23.599999999999998)
# TimePoint(taxi_id=50, name='drop off', time=23.599999999999998)
# TimePoint(taxi_id=504, name='pick up', time=23.599999999999998)
# TimePoint(taxi_id=113, name='end shift', time=23.599999999999998)
# TimePoint(taxi_id=759, name='pick up', time=23.599999999999998)
# TimePoint(taxi_id=126, name='drop off', time=23.599999999999998)
# TimePoint(taxi_id=323, name='drop off', time=23.6)
# TimePoint(taxi_id=747, name='pick up', time=23.6)
# TimePoint(taxi_id=4, name='pick up', time=23.6)
# TimePoint(taxi_id=965, name='end shift', time=23.600000000000005)
# TimePoint(taxi_id=302, name='drop off', time=23.600000000000005)
# TimePoint(taxi_id=863, name='pick up', time=23.600000000000005)
# TimePoint(taxi_id=190, name='drop off', time=23.600000000000005)
# TimePoint(taxi_id=525, name='drop off', time=23.60000000000001)
# TimePoint(taxi_id=265, name='drop off', time=23.60000000000001)
# TimePoint(taxi_id=565, name='drop off', time=23.616666666666664)
# TimePoint(taxi_id=684, name='drop off', time=23.616666666666664)
# TimePoint(taxi_id=866, name='drop off', time=23.616666666666667)
# TimePoint(taxi_id=931, name='drop off', time=23.616666666666667)
# TimePoint(taxi_id=610, name='end shift', time=23.616666666666667)
# TimePoint(taxi_id=42, name='pick up', time=23.61666666666667)
# TimePoint(taxi_id=204, name='end shift', time=23.61666666666667)
# TimePoint(taxi_id=91, name='drop off', time=23.616666666666674)
# TimePoint(taxi_id=615, name='drop off', time=23.616666666666674)
# TimePoint(taxi_id=833, name='pick up', time=23.616666666666678)
# TimePoint(taxi_id=229, name='end shift', time=23.633333333333326)
# TimePoint(taxi_id=434, name='end shift', time=23.633333333333326)
# TimePoint(taxi_id=427, name='end shift', time=23.633333333333333)
# TimePoint(taxi_id=889, name='end shift', time=23.633333333333333)
# TimePoint(taxi_id=190, name='pick up', time=23.63333333333334)
# TimePoint(taxi_id=28, name='pick up', time=23.63333333333334)
# TimePoint(taxi_id=924, name='pick up', time=23.63333333333334)
# TimePoint(taxi_id=693, name='pick up', time=23.63333333333334)
# TimePoint(taxi_id=334, name='pick up', time=23.633333333333344)
# TimePoint(taxi_id=896, name='drop off', time=23.633333333333344)
# TimePoint(taxi_id=614, name='pick up', time=23.633333333333344)
# TimePoint(taxi_id=895, name='end shift', time=23.633333333333344)
# TimePoint(taxi_id=903, name='end shift', time=23.64999999999999)
# TimePoint(taxi_id=63, name='drop off', time=23.65)
# TimePoint(taxi_id=415, name='drop off', time=23.65)
# TimePoint(taxi_id=706, name='drop off', time=23.65)
# TimePoint(taxi_id=700, name='end shift', time=23.65)
# TimePoint(taxi_id=715, name='drop off', time=23.650000000000002)
# TimePoint(taxi_id=911, name='drop off', time=23.650000000000002)
# TimePoint(taxi_id=302, name='pick up', time=23.650000000000006)
# TimePoint(taxi_id=444, name='pick up', time=23.650000000000006)
# TimePoint(taxi_id=885, name='drop off', time=23.65000000000001)
# TimePoint(taxi_id=265, name='pick up', time=23.65000000000001)
# TimePoint(taxi_id=725, name='drop off', time=23.66666666666666)
# TimePoint(taxi_id=528, name='drop off', time=23.666666666666664)
# TimePoint(taxi_id=616, name='pick up', time=23.666666666666664)
# TimePoint(taxi_id=109, name='pick up', time=23.666666666666664)
# TimePoint(taxi_id=29, name='pick up', time=23.666666666666668)
# TimePoint(taxi_id=576, name='drop off', time=23.66666666666667)
# TimePoint(taxi_id=922, name='end shift', time=23.66666666666667)
# TimePoint(taxi_id=363, name='drop off', time=23.666666666666682)
# TimePoint(taxi_id=978, name='pick up', time=23.68333333333333)
# TimePoint(taxi_id=224, name='drop off', time=23.683333333333334)
# TimePoint(taxi_id=323, name='pick up', time=23.683333333333334)
# TimePoint(taxi_id=650, name='drop off', time=23.683333333333337)
# TimePoint(taxi_id=525, name='pick up', time=23.68333333333334)
# TimePoint(taxi_id=397, name='drop off', time=23.683333333333344)
# TimePoint(taxi_id=880, name='drop off', time=23.683333333333344)
# TimePoint(taxi_id=467, name='drop off', time=23.683333333333344)
# TimePoint(taxi_id=551, name='drop off', time=23.69999999999999)
# TimePoint(taxi_id=706, name='pick up', time=23.7)
# TimePoint(taxi_id=296, name='drop off', time=23.7)
# TimePoint(taxi_id=50, name='pick up', time=23.7)
# TimePoint(taxi_id=931, name='pick up', time=23.7)
# TimePoint(taxi_id=666, name='drop off', time=23.7)
# TimePoint(taxi_id=418, name='drop off', time=23.7)
# TimePoint(taxi_id=318, name='drop off', time=23.7)
# TimePoint(taxi_id=63, name='pick up', time=23.7)
# TimePoint(taxi_id=715, name='pick up', time=23.700000000000003)
# TimePoint(taxi_id=598, name='end shift', time=23.700000000000003)
# TimePoint(taxi_id=152, name='drop off', time=23.700000000000003)
# TimePoint(taxi_id=364, name='drop off', time=23.700000000000003)
# TimePoint(taxi_id=307, name='pick up', time=23.700000000000006)
# TimePoint(taxi_id=576, name='pick up', time=23.700000000000006)
# TimePoint(taxi_id=684, name='pick up', time=23.716666666666665)
# TimePoint(taxi_id=152, name='pick up', time=23.71666666666667)
# TimePoint(taxi_id=646, name='drop off', time=23.71666666666667)
# TimePoint(taxi_id=567, name='drop off', time=23.71666666666667)
# TimePoint(taxi_id=155, name='drop off', time=23.716666666666672)
# TimePoint(taxi_id=867, name='drop off', time=23.716666666666672)
# TimePoint(taxi_id=615, name='pick up', time=23.716666666666676)
# TimePoint(taxi_id=415, name='pick up', time=23.73333333333333)
# TimePoint(taxi_id=911, name='pick up', time=23.733333333333334)
# TimePoint(taxi_id=866, name='pick up', time=23.733333333333334)
# TimePoint(taxi_id=296, name='pick up', time=23.733333333333334)
# TimePoint(taxi_id=224, name='pick up', time=23.733333333333334)
# TimePoint(taxi_id=868, name='end shift', time=23.733333333333338)
# TimePoint(taxi_id=462, name='drop off', time=23.73333333333334)
# TimePoint(taxi_id=397, name='pick up', time=23.733333333333345)
# TimePoint(taxi_id=704, name='drop off', time=23.733333333333345)
# TimePoint(taxi_id=796, name='end shift', time=23.73333333333335)
# TimePoint(taxi_id=126, name='end shift', time=23.749999999999996)
# TimePoint(taxi_id=623, name='drop off', time=23.749999999999996)
# TimePoint(taxi_id=442, name='drop off', time=23.75)
# TimePoint(taxi_id=242, name='drop off', time=23.750000000000004)
# TimePoint(taxi_id=93, name='drop off', time=23.750000000000004)
# TimePoint(taxi_id=688, name='drop off', time=23.750000000000004)
# TimePoint(taxi_id=91, name='end shift', time=23.750000000000007)
# TimePoint(taxi_id=467, name='pick up', time=23.75000000000001)
# TimePoint(taxi_id=885, name='pick up', time=23.75000000000001)
# TimePoint(taxi_id=551, name='pick up', time=23.766666666666655)
# TimePoint(taxi_id=69, name='end shift', time=23.766666666666662)
# TimePoint(taxi_id=528, name='pick up', time=23.766666666666666)
# TimePoint(taxi_id=418, name='pick up', time=23.766666666666666)
# TimePoint(taxi_id=567, name='pick up', time=23.76666666666667)
# TimePoint(taxi_id=462, name='pick up', time=23.766666666666676)
# TimePoint(taxi_id=552, name='drop off', time=23.766666666666676)
# TimePoint(taxi_id=392, name='drop off', time=23.766666666666676)
# TimePoint(taxi_id=318, name='pick up', time=23.78333333333333)
# TimePoint(taxi_id=954, name='drop off', time=23.78333333333333)
# TimePoint(taxi_id=230, name='drop off', time=23.78333333333333)
# TimePoint(taxi_id=71, name='drop off', time=23.783333333333335)
# TimePoint(taxi_id=364, name='pick up', time=23.783333333333335)
# TimePoint(taxi_id=93, name='pick up', time=23.78333333333334)
# TimePoint(taxi_id=477, name='drop off', time=23.78333333333334)
# TimePoint(taxi_id=867, name='pick up', time=23.78333333333334)
# TimePoint(taxi_id=650, name='pick up', time=23.78333333333334)
# TimePoint(taxi_id=245, name='drop off', time=23.783333333333346)
# TimePoint(taxi_id=808, name='drop off', time=23.78333333333335)
# TimePoint(taxi_id=80, name='drop off', time=23.79999999999999)
# TimePoint(taxi_id=765, name='drop off', time=23.799999999999997)
# TimePoint(taxi_id=701, name='drop off', time=23.799999999999997)
# TimePoint(taxi_id=495, name='drop off', time=23.8)
# TimePoint(taxi_id=827, name='drop off', time=23.800000000000008)
# TimePoint(taxi_id=896, name='end shift', time=23.80000000000001)
# TimePoint(taxi_id=392, name='pick up', time=23.80000000000001)
# TimePoint(taxi_id=871, name='drop off', time=23.80000000000001)
# TimePoint(taxi_id=363, name='pick up', time=23.800000000000015)
# TimePoint(taxi_id=725, name='end shift', time=23.816666666666663)
# TimePoint(taxi_id=256, name='drop off', time=23.816666666666663)
# TimePoint(taxi_id=565, name='end shift', time=23.816666666666666)
# TimePoint(taxi_id=464, name='drop off', time=23.816666666666666)
# TimePoint(taxi_id=939, name='drop off', time=23.816666666666666)
# TimePoint(taxi_id=100, name='drop off', time=23.81666666666667)
# TimePoint(taxi_id=242, name='pick up', time=23.81666666666667)
# TimePoint(taxi_id=646, name='pick up', time=23.81666666666667)
# TimePoint(taxi_id=155, name='pick up', time=23.816666666666674)
# TimePoint(taxi_id=880, name='pick up', time=23.816666666666677)
# TimePoint(taxi_id=226, name='drop off', time=23.83333333333333)
# TimePoint(taxi_id=851, name='drop off', time=23.83333333333333)
# TimePoint(taxi_id=666, name='end shift', time=23.833333333333332)
# TimePoint(taxi_id=688, name='pick up', time=23.833333333333336)
# TimePoint(taxi_id=321, name='drop off', time=23.833333333333336)
# TimePoint(taxi_id=80, name='pick up', time=23.84999999999999)
# TimePoint(taxi_id=590, name='drop off', time=23.849999999999994)
# TimePoint(taxi_id=770, name='end shift', time=23.849999999999998)
# TimePoint(taxi_id=979, name='drop off', time=23.85)
# TimePoint(taxi_id=293, name='drop off', time=23.850000000000005)
# TimePoint(taxi_id=552, name='pick up', time=23.85000000000001)
# TimePoint(taxi_id=701, name='pick up', time=23.866666666666664)
# TimePoint(taxi_id=400, name='drop off', time=23.866666666666667)
# TimePoint(taxi_id=529, name='drop off', time=23.86666666666667)
# TimePoint(taxi_id=605, name='drop off', time=23.883333333333315)
# TimePoint(taxi_id=227, name='drop off', time=23.883333333333333)
# TimePoint(taxi_id=954, name='end shift', time=23.883333333333333)
# TimePoint(taxi_id=442, name='pick up', time=23.883333333333333)
# TimePoint(taxi_id=105, name='drop off', time=23.883333333333336)
# TimePoint(taxi_id=979, name='pick up', time=23.883333333333336)
# TimePoint(taxi_id=100, name='end shift', time=23.88333333333334)
# TimePoint(taxi_id=704, name='end shift', time=23.883333333333347)
# TimePoint(taxi_id=808, name='end shift', time=23.88333333333335)
# TimePoint(taxi_id=266, name='drop off', time=23.899999999999995)
# TimePoint(taxi_id=226, name='pick up', time=23.899999999999995)
# TimePoint(taxi_id=15, name='drop off', time=23.900000000000002)
# TimePoint(taxi_id=821, name='drop off', time=23.900000000000002)
# TimePoint(taxi_id=719, name='drop off', time=23.900000000000006)
# TimePoint(taxi_id=326, name='drop off', time=23.90000000000001)
# TimePoint(taxi_id=827, name='pick up', time=23.90000000000001)
# TimePoint(taxi_id=851, name='pick up', time=23.91666666666666)
# TimePoint(taxi_id=256, name='pick up', time=23.916666666666664)
# TimePoint(taxi_id=321, name='end shift', time=23.916666666666668)
# TimePoint(taxi_id=959, name='drop off', time=23.916666666666675)
# TimePoint(taxi_id=382, name='drop off', time=23.91666666666668)
# TimePoint(taxi_id=590, name='pick up', time=23.933333333333326)
# TimePoint(taxi_id=939, name='pick up', time=23.933333333333334)
# TimePoint(taxi_id=464, name='end shift', time=23.933333333333334)
# TimePoint(taxi_id=71, name='end shift', time=23.933333333333337)
# TimePoint(taxi_id=600, name='drop off', time=23.933333333333337)
# TimePoint(taxi_id=529, name='pick up', time=23.933333333333337)
# TimePoint(taxi_id=871, name='end shift', time=23.933333333333344)
# TimePoint(taxi_id=245, name='end shift', time=23.933333333333348)
# TimePoint(taxi_id=623, name='end shift', time=23.95)
# TimePoint(taxi_id=227, name='pick up', time=23.95)
# TimePoint(taxi_id=29, name='drop off', time=23.950000000000003)
# TimePoint(taxi_id=719, name='pick up', time=23.950000000000006)
# TimePoint(taxi_id=291, name='drop off', time=23.950000000000014)
# TimePoint(taxi_id=984, name='drop off', time=23.950000000000014)
# TimePoint(taxi_id=605, name='pick up', time=23.966666666666647)
# TimePoint(taxi_id=931, name='drop off', time=23.966666666666665)
# TimePoint(taxi_id=235, name='drop off', time=23.966666666666665)
# TimePoint(taxi_id=230, name='end shift', time=23.966666666666665)
# TimePoint(taxi_id=266, name='end shift', time=23.966666666666665)
# TimePoint(taxi_id=540, name='drop off', time=23.96666666666667)
# TimePoint(taxi_id=706, name='drop off', time=23.983333333333334)
# TimePoint(taxi_id=821, name='pick up', time=23.983333333333334)
# TimePoint(taxi_id=495, name='end shift', time=23.983333333333334)
# TimePoint(taxi_id=15, name='end shift', time=23.983333333333334)
# TimePoint(taxi_id=105, name='end shift', time=23.983333333333338)
# TimePoint(taxi_id=829, name='drop off', time=23.983333333333338)
# TimePoint(taxi_id=477, name='end shift', time=23.983333333333338)
# TimePoint(taxi_id=833, name='drop off', time=23.983333333333345)
# TimePoint(taxi_id=175, name='drop off', time=23.983333333333345)
# TimePoint(taxi_id=765, name='end shift', time=23.999999999999996)
# TimePoint(taxi_id=262, name='drop off', time=24.0)
